# %%
print(diabetes_df.head())
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
import pandas as pd
diabetes_df = pd.read_csv("diabetes_clean.csv")

# %%
diabetes_filtered_df = diabetes_df[diabetes_df['bmi'] > 0]

# %%
print(diabetes_filtered_df.shape)
# Out:
# (757, 9)

# %%
print(diabetes_filtered_df['bmi'].min())
# Out:
# 18.2

# %%
X = diabetes_df.drop("glucose", axis=1).values
y = diabetes_df["glucose"].values
print(type(X), type(y))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt

plt.scatter(X_bmi, y)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.scatter(X_bmi, y)
#       4 plt.ylabel("Blood Glucose (mg/dl)")
#       5 plt.xlabel("Body Mass Index")
#       6
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:4128, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    4108 @_copy_docstring_and_deprecators(Axes.scatter)
#    4109 def scatter(
#    4110     x: float | ArrayLike,
#    (...)   4126     **kwargs,
#    4127 ) -> PathCollection:
# -> 4128     __ret = gca().scatter(
#    4129         x,
#    4130         y,
#    4131         s=s,
#    4132         c=c,
#    4133         marker=marker,
#    4134         cmap=cmap,
#    4135         norm=norm,
#    4136         vmin=vmin,
#    4137         vmax=vmax,
#    4138         alpha=alpha,
#    4139         linewidths=linewidths,
#    4140         edgecolors=edgecolors,
#    4141         colorizer=colorizer,
#    4142         plotnonfinite=plotnonfinite,
#    4143         **({"data": data} if data is not None else {}),
#    4144         **kwargs,
#    4145     )
#    4146     sci(__ret)
#    4147     return __ret
#
#     [... skipping hidden 2 frame]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_axes.py:5329, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    5327 y = np.ma.ravel(y)
#    5328 if x.size != y.size:
# -> 5329     raise ValueError("x and y must be the same size")
#    5331 if s is None:
#    5332     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    5333          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl.metadata (126 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\users\ygor\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ygor\appdata\roaming\python\python313\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ygor\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ygor\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ------------------------------ --------- 7.1/9.3 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 30.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 32.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.1-cp313-cp313-win_amd64.whl (70 kB)
# Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ------------------------------------- -- 6.8/7.2 MB 33.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 30.2 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------- ----------------- 4/7 [cycler]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 kiwisolver-1.5.1 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\Ygor\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.scatter(X_bmi, y)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.scatter(X_bmi, y)
#       4 plt.ylabel("Blood Glucose (mg/dl)")
#       5 plt.xlabel("Body Mass Index")
#       6
#
# NameError: name 'X_bmi' is not defined

# %%
X_bmi = diabetes_filtered_df['bmi']
y = diabetes_filtered_df['triceps']

plt.scatter(X_bmi, y)
plt.ylabel("Blood triceps (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()

# %%
X_bmi = diabetes_filtered_df['bmi']
y = diabetes_filtered_df['insulin']

plt.scatter(X_bmi, y)
plt.ylabel("Blood insulin (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()

# %%
X_bmi = diabetes_filtered_df['bmi']
y = diabetes_filtered_df['glucose']

plt.scatter(X_bmi, y)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()

# %%
X_bmi = diabetes_filtered_df[['bmi']]   # colchete duplo → 2D
y = diabetes_filtered_df['glucose']      # colchete simples → 1D está OK para y

reg=LinearRegression()
reg.fit(X_bmi, y)
predictions = reg.predict(X_bmi)

plt.scatter(X_bmi, y)
plt.plot(X_bmi, predictions)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 X_bmi = diabetes_filtered_df[['bmi']]   # colchete duplo → 2D
#       2 y = diabetes_filtered_df['glucose']      # colchete simples → 1D está OK para y
#       3
# ----> 4 reg=LinearRegression()
#       5 reg.fit(X_bmi, y)
#       6 predictions = reg.predict(X_bmi)
#       7
#
# NameError: name 'LinearRegression' is not defined

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# 'pip' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\ygor\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.5.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.18.1-cp313-cp313-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.25.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------- ----------- 5.8/8.2 MB 33.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 26.3 MB/s eta 0:00:00
# Downloading joblib-1.6.0-py3-none-any.whl (306 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading narwhals-2.25.0-py3-none-any.whl (467 kB)
# Downloading scipy-1.18.1-cp313-cp313-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    --------- ------------------------------ 8.7/36.6 MB 41.1 MB/s eta 0:00:01
#    ------------------ --------------------- 17.3/36.6 MB 40.5 MB/s eta 0:00:01
#    --------------------------- ------------ 25.4/36.6 MB 39.5 MB/s eta 0:00:01
#    ------------------------------------ --- 33.0/36.6 MB 38.4 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 35.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, cloudpickle, joblib, scikit-learn
#
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------ --------------------------------- 1/6 [scipy]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    ------------- -------------------------- 2/6 [narwhals]
#    -------------------- ------------------- 3/6 [cloudpickle]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    -------------------------- ------------- 4/6 [joblib]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [scikit-learn]
#    ---------------------------------------- 6/6 [scikit-learn]
#
# Successfully installed cloudpickle-3.1.2 joblib-1.6.0 narwhals-2.25.0 scikit-learn-1.9.0 scipy-1.18.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
X_bmi = diabetes_filtered_df[['bmi']]   # colchete duplo → 2D
y = diabetes_filtered_df['glucose']      # colchete simples → 1D está OK para y

reg=LinearRegression()
reg.fit(X_bmi, y)
predictions = reg.predict(X_bmi)

plt.scatter(X_bmi, y)
plt.plot(X_bmi, predictions)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd

sales_df = pd.read_csv("advertising_and_sales_clean.csv")

# %%
import numpy as np

# Create X from the radio column's values
X = sales_df["radio"].values

# Create y from the sales column's values
y = sales_df["sales"].values

# Reshape X
X = X.reshape(-1, 1)

# Check the shape of the features and targets
print(X.shape, y.shape)
# Out:
# (4546, 1) (4546,)

# %%
# Import LinearRegression
from sklearn.linear_model import LinearRegression

# Create the model
reg = LinearRegression()

# Fit the model to the data
reg.fit(X, y)

# Make predictions
predictions = reg.predict(X)

print(predictions[:5])
# Out:
# [ 95491.17119147 117829.51038393 173423.38071499 291603.11444202
#  111137.28167129]

# %%
# Import matplotlib.pyplot
import matplotlib.pyplot as plt

# Create scatter plot
plt.scatter(X, y, color="blue")

# Create line plot
plt.plot(X, predictions, color="red")
plt.xlabel("Radio Expenditure ($)")
plt.ylabel("Sales ($)")

# Display the plot
plt.show()
